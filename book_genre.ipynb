# %% [markdown]
# <a href="https://colab.research.google.com/github/Elifglr3/book-genre-classifier/blob/main/book_genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from collections import defaultdict
import time

# %%
def get_book_genre(book_title):
    url = "https://www.googleapis.com/books/v1/volumes"
    params = {
        "q": book_title,
        "maxResults": 1,
        "printType": "books",
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data.get("items")
        if items:
            volume_info = items[0].get("volumeInfo", {})
            categories = volume_info.get("categories", ["Bilinmeyen"])
            return categories[0]
    return "Bilinmeyen"

# %%
# Kitap isimlerini al
book_titles = []
print("Kitap isimlerini girin (bitirmek için boş bir satır bırakın):")
while True:
    title = input("Kitap adı: ").strip()
    if not title:
        break
    book_titles.append(title)
# Out:
# Kitap isimlerini girin (bitirmek için boş bir satır bırakın):
# Kitap adı: nohut
# Kitap adı: satış 101
# Kitap adı: gece yarısı kütüphanesi
# Kitap adı:

# %%
# Kitapları türlerine göre ayır
genre_dict = defaultdict(list)

# %%
for title in book_titles:
    print(f"Tür alınıyor: {title}")
    genre = get_book_genre(title)
    genre_dict[genre].append(title)
    time.sleep(1)  # API'yı çok hızlı sorgulamamak için gecikme
# Out:
# Tür alınıyor: nohut
# Tür alınıyor: satış 101
# Tür alınıyor: gece yarısı kütüphanesi

# %%
# Sonuçları yazdır
print("\nKitaplar türlerine göre:")
for genre, titles in genre_dict.items():
    print(f"\n📚 {genre}:")
    for t in titles:
        print(f"  - {t}")
# Out:
# Kitaplar türlerine göre:
#
# 📚 Fiction:
#   - nohut
#   - gece yarısı kütüphanesi
#
# 📚 Education:
#   - satış 101
